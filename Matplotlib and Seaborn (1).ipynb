# %% [markdown]
# # Data Visualization Using Python
#
# Python offers several plotting libraries, namely Matplotlib, Seaborn, and may other such data visualization packages with different features for creating informative, customized, and appealing plots to present data in the most simple and effective way.

# %% [markdown]
# ## Matplotlib and Seaborn
#
# Matplotlib and Seaborn are Python libraries that use for data visualization. They have inbuilt modules for plotting different graphs. While Matplotlib is used to embed graphs into applications, Seaborn is primarily used for statistical graphs.

# %% [markdown]
# ### Matplotlib
# - It is used for basic graph plotting like Line Chart, Bar Graphs, etc.
# - It mainly works with datasets and arrays.
# - Matplotlib acts productively with data arrays and frames. It regards the aces and figures as objects.
# - Matplotlib is more customizable and pairs well with Pandas and Numpy for Exploratory Data Analysis.

# %% [markdown]
# ### Seaborn
# - It is mainly used for statistics visualization and can perform complex visualizations with fewer commands.
# - It works with entire datasets.
# - Seaborn is considerably more organized and functional than Matplotlib and treats the entire dataset as a solitary unit.
# - Seaborn has more inbuilt themes and is mainly used for statistical analysis.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Line Chart
#
# A line chart is a graph that represents information as a series of data points connected by a straight line. In line charts, each data point or marker is plotted and connected with a line or curve.
#
# Let's consider the apple yield (tons per hectare) in Kanto. Let's plot a line graph using this data and see how the yield of apples and manggo changes over time. We are going to both plot by using Matplotlib and Seaborn as follows:

# %% [markdown]
# ### Using Matplotlib
#
# We are using random data points to represents the yield of apples

# %%
apples = [0.89, 0.92, 0.94, 0.96, 0.96, 0.92, 0.94]

# %% [markdown]
# After we define the data points of apples yields, we are going to plot its Line Chart using Matplotlib

# %%
plt.plot(apples)

# %% [markdown]
# To better understand the graph and its purpose, we can add the x-axis values too

# %%
# add the years for better understanding the graph
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017]
apples = [0.89, 0.92, 0.94, 0.96, 0.96, 0.92, 0.94] #ton per hectare

# %% [markdown]
# Since we have the 'years' variable as the x-axis, we need to type it bedore the 'apples' variable below

# %%
# plt.plot(x,y)

plt.plot(years, apples)

# %% [markdown]
# Let's add labels to the axes so that we can show what each axis represents

# %%
plt.plot(years, apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
# Out:
# Text(0, 0.5, 'Yield (tons per hectare)')

# %% [markdown]
# To plot multiple datasets on the same grapgh, just use the plt.plot function once for each dataset. Let's use this to compare the yields of apples vs manggo on the same graph

# %%
apples = [0.89, 0.92, 0.90, 0.93, 0.92, 0.92, 0.94] 
manggo = [0.93, 0.91, 0.92, 0.90, 0.92, 0.94, 0.94]

# %%
plt.plot(years, apples)
plt.plot(years, manggo)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %% [markdown]
# We can add a legend which tells us what each line in our graph means. To understand what we are plotting, we can add a title to our graph.

# %%
plt.plot(years, apples)
plt.plot(years, manggo)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Manggo'])

# %% [markdown]
# to plot multiple datasets on th esame graph, just use the plt.plot function once for each datasets. Let's use this to compare the tields of apples vs orange on the same graph

# %%
plt.plot(years, apples) 
plt.plot(years, manggo) 

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)' ) 

plt.title("Appels and manggo in Malang")
plt.legend(['Apples', 'Manggo'])

# %% [markdown]
# we still use the same command from the matplotlib previously, but we will see the difference of adding the sns_set_style command

# %%
plt.plot(years, apples, marker = 'o') 
plt.plot(years, manggo, marker = 'x') 

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)' ) 

plt.title("Apples and manggo in Malang")
plt.legend(['Apples', 'Manggo'])

# %%
# you can also add white grid or darker grid
plt.plot(years, apples, marker = 'o') 
plt.plot(years, manggo, marker = 'x') 

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)' ) 

plt.title("Apples and manggo in Malang")
plt.legend(['Apples', 'Manggo'])

sns.set_style('whitegrid')

# %%
# you can also add white grid or darker grid
plt.plot(years, apples, marker = 'o') 
plt.plot(years, manggo, marker = 'x') 

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)' ) 

plt.title("apples and manggo in Malang")
plt.legend(['apples', 'Manggo'])

sns.set_style('darkgrid')

# %% [markdown]
# If your data in data frame you can use it too for make a graph

# %%
import pandas as pd

# %% [markdown]
# then we will define, appels, and manggo variables in to a new variable

# %%
yeild = dict(Years = years, Apples = apples, Manggo = manggo)
harvest = pd.DataFrame(yeild)
harvest
# Out:
#    Years  Apples  Manggo
# 0   2011    0.89    0.93
# 1   2012    0.92    0.91
# 2   2013    0.90    0.92
# 3   2014    0.93    0.90
# 4   2015    0.92    0.92
# 5   2016    0.92    0.94
# 6   2017    0.94    0.94

# %% [markdown]
# then we can plot them using seaborn as below

# %%
ax = sns.lineplot(x='Years', y='Apples', data = harvest)
ax1 = sns.lineplot(x ='Years', y ='Manggo', data = harvest)

plt.show()
# Out:
# C:\Users\MyBook Hype\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MyBook Hype\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MyBook Hype\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Using Matplotlib
plt.bar(years, manggo) #plt.baru(x,y)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Harvest data in Indramayu")
# Out:
# Text(0.5, 1.0, 'Harvest data in Indramayu')

# %%
# Use stacked bar chart
plt.bar(years, apples)
plt.bar(years, manggo, bottom=manggo)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ## Barplot

# %%
df = sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.barplot(x = 'cut',
            y = 'price',
            data = df)
# Out:
# C:\Users\MyBook Hype\AppData\Roaming\Python\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='cut', ylabel='price'>

# %%
if you want compare bar plots side-by-side, tou can use hue argument. The comparison will be done based on th ethird feature specified in this argument.
# Out:
#   Cell In[36], line 1
#     if you want compare bar plots side-by-side, tou can use hue argument. The comparison will be done based on th ethird feature specified in this argument.
#            ^
# SyntaxError: invalid syntax
